# %% [markdown]
# <a href="https://colab.research.google.com/github/abusufianrobin/Dataset-Analysis-and-Prediction/blob/main/Heart_Disease_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Questions:
# 1. Import The Libraries And Dataset
# 2. Display Top 5 Rows of The Dataset
# 3. Check The Last 5 Rows of The Dataset
# 4. Find Shape of Our Dataset (Number of Rows And Number of Columns)
# 5. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
# 6. Check Null Values In The Dataset
# 7. Check For Duplicate Data and Drop Them
# 8. Get Overall Statistics About The Dataset
# 9. Draw Correlation Matrix
# 10. How Many People Have Heart Disease, And How Many Don't Have Heart Disease In This Dataset?
# 11. Find Count of  Male & Female in this Dataset
# 12. Find Gender Distribution According to The Target Variable
# 13. Check Age Distribution In The Dataset
# 14. Check Chest Pain Type
# 15. Show The Chest Pain Distribution As Per Target Variable
# 16. Show Fasting Blood Sugar Distribution According To Target Variable
# 17.  Check Resting Blood Pressure Distribution
# 18. Compare Resting Blood Pressure As Per Sex Column
# 19. Show Distribution of Serum cholesterol
# 20. Plot Continuous Variables

# %% [markdown]
# 1. Import The Libraries And Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('heart.csv')

# %% [markdown]
# *  Age
# *  Sex
#
#
# *   Chest Pain type (4 Values)
# 1) Value 0: Typical Angina
# 2) Value 1: Atypical Angina
# 3) Value 2: Non-Anginal Pain
# 4) Value 3: Asymptomatic
#
# *   Trestbps: resting blood pressure (in mmHg on admission to the Hospital)
# *   Chol: serum Cholestoral in mg/dl
# *   fbs: (fasting blood sugar > 120 mg/dl)(1 = True; 0 = False)
# *   Restecg: resting electrocardiographic results
#   1. Value 0: Normal
#   2. Value 1: Having ST-T wave abnormality(T wave invensions and/or ST elevation or depression of > 0.05 mV)
#   3. Value 2: Showing propable or definite left ventricular hypertrophy by 'Estes' criteria
#
#
# *   Thalach: Maximum heart rate achieved
# *   Exang: Exercise induced Angina(1 = Yes; 0= No)
#
#
# *   oldpeak : ST depression induced by exercise relative to rest
# *   Slope: The slope of the peak exercise ST segment
#
# 1. Value 1: Upsloping
# 2. Value 2: flat
# 3. Value 3: Downsloping
#
#
#
# *   Ca: Number of Major vessels(0-3) colored by flourosopy
# *   Thal: 3 = Normal; 6 = Fixed Defect; 7 = Reversable defect
#
#
# *   Target: 0 = Less chance of heart attack; 1 = more chance of heart attack

# %% [markdown]
# 2. Display Top 5 Rows of The Dataset

# %%
data.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# 3. Check The Last 5 Rows of The Dataset

# %%
data.tail(15)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 288   57    1   0       110   335    0        1      143      1      3.0
# 289   55    0   0       128   205    0        2      130      1      2.0
# 290   61    1   0       148   203    0        1      161      0      0.0
# 291   58    1   0       114   318    0        2      140      0      4.4
# 292   58    0   0       170   225    1        0      146      1      2.8
# 293   67    1   2       152   212    0        0      150      0      0.8
# 294   44    1   0       120   169    0        1      144      1      2.8
# 295   63    1   0       140   187    0        0      144      1      4.0
# 296   63    0   0       124   197    0        1      136      1      0.0
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# ...

# %% [markdown]
# 4. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
# Q No 4: Find Shape of Our Dataset (Number of Rows And Number of Columns)

data.shape
print("Number of Rows:",data.shape[0])
print("Number of Columns:",data.shape[1])
# Out:
# Number of Rows: 303
# Number of Columns: 14

# %% [markdown]
# 5. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
# Q No 5: Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# 6. Check Null Values In The Dataset

# %%
# Q No 6: Check Null Values In The Dataset


data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# 7. Check For Duplicate Data and Drop Them

# %%
# Q No 7; Check For Duplicate Data and Drop Them

data_dup= data.duplicated().any()
print("Duplicate Found:",data_dup)

data = data.drop_duplicates()
data.shape
# Out:
# Duplicate Found: True
# (302, 14)

# %% [markdown]
# 8. Get Overall Statistics About The Dataset

# %%
# Q No 8: Get Overall Statistics About The Dataset

data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# 9. Draw Correlation Matrix

# %%
# Q No 9: Draw Correlation Matrix

plt.figure(figsize=(15,6))
sns.heatmap(data.corr(), annot= True)
# Out:
# <Axes: >

# %% [markdown]
# 10. How Many People Have Heart Disease, And How Many Don't Have Heart Disease In This Dataset?

# %%
# Q No 10: How Many People Have Heart Disease, And How Many Don't Have Heart Disease In This Dataset?

data.columns
print("Number of People Have Heart Disease:",data['target'].value_counts())
# Out:
# Number of People Have Heart Disease: target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
target_counts = data['target'].value_counts()

# Create the bar plot
sns.barplot(x=target_counts.index, y=target_counts.values, palette=['green', 'red'])

# Set the labels
plt.xlabel('Target')
plt.ylabel('Frequency')

# Display the plot
plt.xticks([0,1],['No', 'Yes'])
plt.show()
# Out:
# <ipython-input-12-1365ec299446>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=target_counts.index, y=target_counts.values, palette=['green', 'red'])

# %% [markdown]
# 11. Find Count of Male & Female in this Dataset

# %%
# Q No 11: Find Count of Male & Female in this Dataset

print("Number of Male & Female:",data['sex'].value_counts())
# Out:
# Number of Male & Female: sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
target_counts = data['sex'].value_counts()

# Create the bar plot
sns.barplot(x=target_counts.index, y=target_counts.values, palette=['orange', 'blue'])

# Set the labels
plt.xlabel('sex')
plt.ylabel('Frequency')

# Display the plot
plt.xticks([0,1],['Female', 'Male'])
plt.show()
# Out:
# <ipython-input-14-f707f145933d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=target_counts.index, y=target_counts.values, palette=['orange', 'blue'])

# %% [markdown]
# 12. Find Gender Distribution According to The Target Variable

# %%
# Q No 12: Find Gender Distribution According to The Target Variable

data.columns

sns.countplot(x='sex', hue = 'target', data=data)

plt.xticks([1,0],['Male', 'Female'])
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# 13. Check Age Distribution In The Dataset

# %%
# Q No 13: Check Age Distribution In The Dataset

sns.displot(data['age'],bins=20)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Create the bar chart with the distribution line
sns.histplot(data['age'], bins=20, kde=True)

# Set the labels (optional)
plt.xlabel('Age')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# 14. Check Chest Pain Type
#
# Chest Pain type (4 Values) :
#
# *   Value 0: Typical Angina
# *   Value 1: Atypical Angina
# *   Value 2: Non-Anginal Pain
# *   Value 3: Asymptomatic

# %%
# Q No 14: Check Chest Pain Type

sns.countplot(x='cp', data=data, palette='viridis')

# Setting custom labels for the x-axis
plt.xticks([0, 1, 2, 3], ["Typical Angina", "Atypical Angina", "Non-Anginal Pain", "Asymptomatic"])

# Rotate x-axis labels if necessary
plt.xticks(rotation=75)

# Show the plot
plt.show()
# Out:
# <ipython-input-18-6e1f595a94ad>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='cp', data=data, palette='viridis')

# %% [markdown]
# 15. Show The Chest Pain Distribution As Per Target Variable

# %%
# Q No 15: Show The Chest Pain Distribution As Per Target Variable

sns.countplot(x='cp', hue = 'target', data= data)
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# 16. Show Fasting Blood Sugar Distribution According To Target Variable

# %%
# Q No 16: Show Fasting Blood Sugar Distribution According To Target Variable

sns.countplot(x='fbs', hue = 'target', data= data)
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# 17. Check Resting Blood Pressure Distribution

# %%
# Q No 17: Check Resting Blood Pressure Distribution

data['trestbps'].hist()
# Out:
# <Axes: >

# %% [markdown]
# 18. Compare Resting Blood Pressure As Per Sex Column

# %%
# Q No 18: Compare Resting Blood Pressure As Per Sex Column

g = sns.FacetGrid(data, hue = "sex", aspect = 4)
g.map(sns.kdeplot, 'trestbps', shade = True)

plt.legend(labels = ['Male', 'Female'])
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# 19. Show Distribution of Serum cholesterol

# %%
# Q No 19: Show Distribution of Serum cholesterol

data['chol'].hist()
# Out:
# <Axes: >

# %% [markdown]
# 20. Plot Continuous Variables

# %%
# Q No 20: Plot Continuous Variables

data.columns

cate_val =[]
cont_val =[]

for column in data.columns:
  if data[column].nunique() <=10:
    cate_val.append(column)

  else:
    cont_val.append(column)

print("Categorical Values:",cate_val)


print("Continuous Values:", cont_val)


data.hist(cont_val, figsize=(15,6))
plt.tight_layout()
plt.show()
# Out:
# Categorical Values: ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']
# Continuous Values: ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
